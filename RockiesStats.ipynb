# %%
import pandas as pd
import numpy as np

# %%
Rockies_Pitching = pd.read_csv('/Users/Camer/Downloads/Datasets/Rockies Stats/COL_pitching.csv')
Rockies_Batting = pd.read_csv('/Users/Camer/Downloads/Datasets/Rockies Stats/COL_batting.csv')

# %%
Rockies_Batting = Rockies_Batting.set_index('Rank')
Rockies_Pitching = Rockies_Pitching.set_index('Rank')

# %%
Rockies_Batting.head()
# Out:
#       Year Position              Name  Age  Games  Plate_Appearances  At_Bats  \
# Rank
# 1     2023        C        Elías Díaz   32    141                526      486
# 2     2023       1B  Elehuris Montero   24     85                307      284
# 3     2023       2B     Harold Castro   29     99                270      258
# 4     2023       SS    Ezequiel Tovar   21    153                615      581
# 5     2023       3B      Ryan McMahon   28    152                627      555
#
#       Runs  Hits  Doubles  ...  On_Base_Plus_Slugging_Percentage  \
# Rank                       ...
# 1       48   130       25  ...                             0.725
# 2       40    69       15  ...                             0.716
# 3       24    65       13  ...                             0.589
# 4       79   147       37  ...                             0.695
# 5       80   133       31  ...                             0.753
#
#       On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# ...

# %%
Rockies_Pitching.head()
# Out:
#       Year Position            Name  Age  Wins  Losses  Winning_Percentage  \
# Rank
# 1     2023       SP   Kyle Freeland   30     6      14               0.300
# 2     2023       SP   Austin Gomber   29     9       9               0.500
# 3     2023       SP  Chase Anderson   35     1       6               0.143
# 4     2023       SP        Ty Blach   32     3       3               0.500
# 5     2023       SP    Chris Flexen   28     2       4               0.333
#
#       Earned_Run_Average  Games_Played  Games_Started  ...  \
# Rank                                                   ...
# 1                   5.03            29             29  ...
# 2                   5.50            27             27  ...
# 3                   5.75            17             17  ...
# 4                   5.54            20             13  ...
# 5                   6.27            12             12  ...
#
#       Adjusted_Earned_Run_Average  Fielding_Independent_Pitching  \
# Rank
# ...

# %%
Rockies_Batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1443 entries, 1 to 46
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Year                                   1443 non-null   int64
#  1   Position                               1440 non-null   object
#  2   Name                                   1443 non-null   object
#  3   Age                                    1443 non-null   int64
#  4   Games                                  1443 non-null   int64
#  5   Plate_Appearances                      1443 non-null   int64
#  6   At_Bats                                1443 non-null   int64
#  7   Runs                                   1443 non-null   int64
#  8   Hits                                   1443 non-null   int64
#  9   Doubles                                1443 non-null   int64
#  10  Triples                                1443 non-null   int64
# ...

# %%
Rockies_Pitching.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 762 entries, 1 to 25
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           762 non-null    int64
#  1   Position                       330 non-null    object
#  2   Name                           762 non-null    object
#  3   Age                            762 non-null    int64
#  4   Wins                           762 non-null    int64
#  5   Losses                         762 non-null    int64
#  6   Winning_Percentage             762 non-null    float64
#  7   Earned_Run_Average             762 non-null    float64
#  8   Games_Played                   762 non-null    int64
#  9   Games_Started                  762 non-null    int64
#  10  Games_Finished                 762 non-null    int64
#  11  Complete_Games                 762 non-null    int64
# ...

# %%
Rockies_Batting.describe()
# Out:
#               Year          Age        Games  Plate_Appearances      At_Bats  \
# count  1443.000000  1443.000000  1443.000000        1443.000000  1443.000000
# mean   2008.185031    28.181566    47.278586         129.751906   115.742204
# std       8.794999     3.826909    45.478638         193.938437   173.263779
# min    1993.000000    20.000000     0.000000           0.000000     0.000000
# 25%    2001.000000    25.000000    12.000000           1.500000     1.000000
# 50%    2008.000000    28.000000    30.000000          31.000000    26.000000
# 75%    2016.000000    31.000000    70.000000         186.000000   168.000000
# max    2023.000000    49.000000   162.000000         732.000000   690.000000
#
#               Runs         Hits      Doubles      Triples    Home_Runs  ...  \
# count  1443.000000  1443.000000  1443.000000  1443.000000  1443.000000  ...
# mean     16.790714    31.432432     6.191961     0.880111     3.816355  ...
# ...

# %%
Rockies_Pitching.describe()
# Out:
#               Year         Age        Wins      Losses  Winning_Percentage  \
# count   762.000000  762.000000  762.000000  762.000000          762.000000
# mean   2008.709974   28.178478    2.965879    3.409449            0.372406
# std       8.854712    3.839713    3.597910    3.609786            0.313190
# min    1993.000000   20.000000    0.000000    0.000000            0.000000
# 25%    2001.000000   25.000000    0.000000    0.250000            0.000000
# 50%    2009.000000   28.000000    2.000000    2.000000            0.385000
# 75%    2016.000000   31.000000    4.000000    5.000000            0.571000
# max    2023.000000   49.000000   19.000000   17.000000            1.000000
#
#        Earned_Run_Average  Games_Played  Games_Started  Games_Finished  \
# count          762.000000    762.000000     762.000000      762.000000
# mean             6.273031     26.098425       6.375328        6.220472
# std              5.901287     21.157057      10.015143       10.494286
# ...

# %%
pd.plotting.scatter_matrix(Rockies_Batting[['Plate_Appearances', 'Home_Runs', 'Batting_Average']])
# Out:
# array([[<Axes: xlabel='Plate_Appearances', ylabel='Plate_Appearances'>,
#         <Axes: xlabel='Home_Runs', ylabel='Plate_Appearances'>,
#         <Axes: xlabel='Batting_Average', ylabel='Plate_Appearances'>],
#        [<Axes: xlabel='Plate_Appearances', ylabel='Home_Runs'>,
#         <Axes: xlabel='Home_Runs', ylabel='Home_Runs'>,
#         <Axes: xlabel='Batting_Average', ylabel='Home_Runs'>],
#        [<Axes: xlabel='Plate_Appearances', ylabel='Batting_Average'>,
#         <Axes: xlabel='Home_Runs', ylabel='Batting_Average'>,
#         <Axes: xlabel='Batting_Average', ylabel='Batting_Average'>]],
#       dtype=object)
