# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ISLP

# %% [markdown]
# # Problem 8 part a

# %%
college = pd.read_csv('/Users/Camer/Downloads/Spring 2025 Classes/Stat 411/Stat 411 Book/All CSV Files/Hitters.csv')

# %% [markdown]
# # Problem 8 part b

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college2 = pd.read_csv('/Users/Camer/Downloads/Spring 2025 Classes/Stat 411/Stat 411 Book/All CSV Files/College.csv', index_col = 0)
college3 = college.rename({'Unnamed: 0': 'College'},
                          axis = 1)
college3 = college3.set_index('College')

# %%
college = college3

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# # Problem 8 part c

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# # Problem 8 part d

# %%
pd.plotting.scatter_matrix(college[['Top10perc','Apps','Enroll']]);

# %% [markdown]
# # Problem 8 part e

# %%
college.boxplot('Outstate', by = 'Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# # Problem 8 part f

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          bins = [0, 50, 100],
                          labels = ['No', 'Yes'])

college['Elite'].value_counts()

# Solution Version: college['Elite'] = pd.cut(college['Top10perc'],bins=2,labels=['No','Yes'])
# Book was wrong so both ways came up with different ways around the problem with only slightly different results.
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot('Outstate', by = 'Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# # Problem 8 part g

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %%
fig, axes =plt.subplots(nrows=2,ncols= 2,figsize=(12,12))
college['Apps'].plot.hist(ax=axes[0,0])
college['Accept'].plot.hist(ax=axes[0,1])
college['Enroll'].plot.hist(ax=axes[1,0])
college['Outstate'].plot.hist(ax=axes[1,1]);

# Old less effecient code below:
# We can create bins for each of the plotted columns
# fig, ax = plt.subplots(2, 2, figsize = (12, 8))
# ax[0, 0].hist(college['Outstate'], bins = 20)
# ax[0, 0].set_title("Out Of State Tuition (bins = 20)")
# ax[0, 1].hist(college['Grad.Rate'], bins = 15)
# ax[0, 1].set_title("Graduation Rate (bins = 15)")
# ax[1, 0].hist(college['Room.Board'], bins = 20)
# ax[1, 0].set_title("Room and Board (bins = 20)")
# ax[1, 1].hist(college['Expend'], bins = 30)
# ax[1, 1].set_title("Instructional expenditure per student (bins = 30)")

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 8))
ax[0, 0].hist(college['F.Undergrad'], bins = 10)
ax[0, 0].set_title("# of Full-Time Undergrads (bins = 10)")
ax[0, 1].hist(college['Books'], bins = 15)
ax[0, 1].set_title("Estimated Book Cost (bins = 15)")
ax[1, 0].hist(college['S.F.Ratio'], bins = 10)
ax[1, 0].set_title("Student to Faculty Ratio (bins = 10)")
ax[1, 1].hist(college['PhD'], bins = 10)
ax[1, 1].set_title("Percent of faculty with Ph.D.s (bins = 10)")
# Out:
# Text(0.5, 1.0, 'Percent of faculty with Ph.D.s (bins = 10)')

# %% [markdown]
# # Problem 8 part h

# %% [markdown]
# After exploring the data some more and messing with the amount of bins some of my interesting findings I were that there is at least one data point in the graduation rate that is above 100%, but other than that most schools had a fairly normal distribution with what looked like 60-70% Graduation Rate being the most frequent result.  Other histograms, like the ones for full-time undergrads and part-time undergrads, were much more skewed and had only a few schools with more than 15,000 students relative to the 700 surveyed.  Lastly I thought the histogram for instructional expenditure per student was quite interesting as you can see that probably 80% or more of the schools expenditure per student was less than $20,000 with only a few really high points.

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %% [markdown]
# We can group the variables into categories such as financial, faculty, and student counts to see if there is relationships between them

# %%
pd.plotting.scatter_matrix(college[['Enroll','F.Undergrad','Top10perc','Top25perc','Accept',
                                    'Apps','Outstate']]);

# %% [markdown]
# We can see a correlation between enroll and F.Undergrad, Accept, and Apps
